# %%
# import the liabreries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
## data load
df=pd.read_csv('Unemployment in India.csv')

# %%
df.head()
# Out:
#            Region         Date  Frequency   Estimated Unemployment Rate (%)  \
# 0  Andhra Pradesh   31-05-2019    Monthly                              3.65
# 1  Andhra Pradesh   30-06-2019    Monthly                              3.05
# 2  Andhra Pradesh   31-07-2019    Monthly                              3.75
# 3  Andhra Pradesh   31-08-2019    Monthly                              3.32
# 4  Andhra Pradesh   30-09-2019    Monthly                              5.17
#
#     Estimated Employed   Estimated Labour Participation Rate (%)   Area
# 0           11999139.0                                     43.24  Rural
# 1           11755881.0                                     42.05  Rural
# 2           12086707.0                                     43.50  Rural
# 3           12285693.0                                     43.97  Rural
# 4           12256762.0                                     44.68  Rural

# %%
df.shape
# Out:
# (768, 7)

# %%
## this dataset 768 row and 7 columns

# %%
df.columns
# Out:
# Index(['Region', ' Date', ' Frequency', ' Estimated Unemployment Rate (%)',
#        ' Estimated Employed', ' Estimated Labour Participation Rate (%)',
#        'Area'],
#       dtype='object')

# %%
## check the datatypes
df.dtypes
# Out:
# Region                                       object
#  Date                                        object
#  Frequency                                   object
#  Estimated Unemployment Rate (%)            float64
#  Estimated Employed                         float64
#  Estimated Labour Participation Rate (%)    float64
# Area                                         object
# dtype: object

# %%
## 4 columns datatype is object and 3 columns datatype is float

# %%
## summary of the dataset
df.describe()
# Out:
#         Estimated Unemployment Rate (%)   Estimated Employed  \
# count                        740.000000         7.400000e+02
# mean                          11.787946         7.204460e+06
# std                           10.721298         8.087988e+06
# min                            0.000000         4.942000e+04
# 25%                            4.657500         1.190404e+06
# 50%                            8.350000         4.744178e+06
# 75%                           15.887500         1.127549e+07
# max                           76.740000         4.577751e+07
#
#         Estimated Labour Participation Rate (%)
# count                                740.000000
# mean                                  42.630122
# std                                    8.111094
# min                                   13.330000
# 25%                                   38.062500
# 50%                                   41.160000
# 75%                                   45.505000
# ...

# %%
## Estimated Unemployment Rate (%) min 0 and maximum is 76.740000. and this dataset count is 740

# %%
## all information of the dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 7 columns):
#  #   Column                                    Non-Null Count  Dtype
# ---  ------                                    --------------  -----
#  0   Region                                    740 non-null    object
#  1    Date                                     740 non-null    object
#  2    Frequency                                740 non-null    object
#  3    Estimated Unemployment Rate (%)          740 non-null    float64
#  4    Estimated Employed                       740 non-null    float64
#  5    Estimated Labour Participation Rate (%)  740 non-null    float64
#  6   Area                                      740 non-null    object
# dtypes: float64(3), object(4)
# memory usage: 42.1+ KB

# %%
## check the missing values
df.isnull().sum()
# Out:
# Region                                      28
#  Date                                       28
#  Frequency                                  28
#  Estimated Unemployment Rate (%)            28
#  Estimated Employed                         28
#  Estimated Labour Participation Rate (%)    28
# Area                                        28
# dtype: int64

# %%
## there are many missing values.handle the missing values using the ffeature engineerning techniques

# %%
## handle the missing values
## using interplotion methods like mean,median,mode or remove the missing values row

# %%
## check the duplicated values
df.duplicated().sum()
# Out:
# 27

# %%
df[df.duplicated()]
# Out:
#     Region  Date  Frequency   Estimated Unemployment Rate (%)  \
# 360    NaN   NaN        NaN                               NaN
# 361    NaN   NaN        NaN                               NaN
# 362    NaN   NaN        NaN                               NaN
# 363    NaN   NaN        NaN                               NaN
# 364    NaN   NaN        NaN                               NaN
# 365    NaN   NaN        NaN                               NaN
# 366    NaN   NaN        NaN                               NaN
# 367    NaN   NaN        NaN                               NaN
# 368    NaN   NaN        NaN                               NaN
# 369    NaN   NaN        NaN                               NaN
# 370    NaN   NaN        NaN                               NaN
# 371    NaN   NaN        NaN                               NaN
# 372    NaN   NaN        NaN                               NaN
# 754    NaN   NaN        NaN                               NaN
# ...

# %%
## this dataset duplicated row 27

# %%
## remove the duplicated row
df=df.drop_duplicates()

# %%
df
# Out:
#              Region         Date  Frequency   Estimated Unemployment Rate (%)  \
# 0    Andhra Pradesh   31-05-2019    Monthly                              3.65
# 1    Andhra Pradesh   30-06-2019    Monthly                              3.05
# 2    Andhra Pradesh   31-07-2019    Monthly                              3.75
# 3    Andhra Pradesh   31-08-2019    Monthly                              3.32
# 4    Andhra Pradesh   30-09-2019    Monthly                              5.17
# ..              ...          ...        ...                               ...
# 749     West Bengal   29-02-2020    Monthly                              7.55
# 750     West Bengal   31-03-2020    Monthly                              6.67
# 751     West Bengal   30-04-2020    Monthly                             15.63
# 752     West Bengal   31-05-2020    Monthly                             15.22
# 753     West Bengal   30-06-2020    Monthly                              9.86
#
# ...

# %%
df['Region'].unique()
# Out:
# array(['Andhra Pradesh', 'Assam', 'Bihar', 'Chhattisgarh', 'Delhi', 'Goa',
#        'Gujarat', 'Haryana', 'Himachal Pradesh', 'Jammu & Kashmir',
#        'Jharkhand', 'Karnataka', 'Kerala', 'Madhya Pradesh',
#        'Maharashtra', 'Meghalaya', 'Odisha', 'Puducherry', 'Punjab',
#        'Rajasthan', 'Sikkim', 'Tamil Nadu', 'Telangana', 'Tripura',
#        'Uttar Pradesh', 'Uttarakhand', 'West Bengal', nan, 'Chandigarh'],
#       dtype=object)

# %%
## this dataset is many region

# %%
df[' Frequency'].unique()
# Out:
# array([' Monthly', nan, 'Monthly'], dtype=object)

# %%
## there are 3 categories of frequency
#1.monthly
#2.nan
#3 monthly

# %%
df[' Estimated Employed']
# Out:
# 0      11999139.0
# 1      11755881.0
# 2      12086707.0
# 3      12285693.0
# 4      12256762.0
#           ...
# 749    10871168.0
# 750    10806105.0
# 751     9299466.0
# 752     9240903.0
# 753     9088931.0
# Name:  Estimated Employed, Length: 741, dtype: float64

# %%
df[' Estimated Employed'].unique()
# Out:
# array([11999139., 11755881., 12086707., 12285693., 12256762., 12017412.,
#        11397681., 12528395., 12016676., 11723617., 11359660.,  8792827.,
#         9526902., 15572975., 11749334.,  8923222.,  9911534.,  9292039.,
#        11468349.,  8395906.,  9625362., 11420996.,  8462814.,  9878742.,
#         9926176.,  7544937., 24322330., 24097712., 23248875., 22260203.,
#        23905700., 24053140., 22445989., 22914530., 23409006., 23168192.,
#        22667882., 14645275., 14050319., 20622566.,  6259019.,  6608626.,
#         6753622.,  6607694.,  6490776.,  7043840.,  6942931.,  6569385.,
#         6236201.,  6847173.,  6894808.,  6534321.,  5454091.,  5781095.,
#          169487.,   149076.,   166605.,   135407.,   166056.,   149511.,
#          178768.,   145671.,   157791.,   147500.,   152413.,   115487.,
#          129610.,   112108.,   179340.,   170471.,   167437.,   183603.,
#          163215.,   177440.,   159489.,   177155.,   158936.,   171672.,
# ...

# %%
df[' Estimated Labour Participation Rate (%)']
# Out:
# 0      43.24
# 1      42.05
# 2      43.50
# 3      43.97
# 4      44.68
#        ...
# 749    44.09
# 750    43.34
# 751    41.20
# 752    40.67
# 753    37.57
# Name:  Estimated Labour Participation Rate (%), Length: 741, dtype: float64

# %%
df[' Estimated Labour Participation Rate (%)'].unique()
# Out:
# array([43.24, 42.05, 43.5 , 43.97, 44.68, 43.01, 41.  , 45.14, 43.46,
#        42.83, 40.66, 36.03, 38.16, 53.76, 57.39, 43.87, 48.21, 45.83,
#        55.67, 40.76, 46.64, 54.9 , 40.17, 47.05, 50.  , 34.38, 39.75,
#        39.71, 39.66, 36.85, 38.57, 40.31, 37.51, 37.25, 37.54, 37.28,
#        38.88, 38.63, 38.5 , 37.4 , 42.89, 43.71, 43.53, 42.55, 43.38,
#        46.28, 43.56, 42.59, 42.03, 45.05, 44.98, 39.43, 35.56, 38.66,
#        42.33, 35.74, 40.53, 35.21, 40.68, 37.9 , 42.71, 37.08, 38.36,
#        35.84, 37.45, 30.21, 34.65, 29.22, 39.16, 38.19, 39.81, 39.61,
#        35.78, 40.36, 44.09, 38.7 , 35.36, 36.11, 45.36, 33.71, 52.03,
#        50.12, 54.21, 50.57, 51.01, 52.27, 54.55, 51.51, 54.07, 53.48,
#        52.06, 34.77, 46.31, 47.72, 45.12, 45.23, 42.17, 48.23, 44.72,
#        46.07, 42.48, 47.4 , 43.74, 45.37, 41.4 , 49.85, 42.78, 48.53,
#        44.23, 41.18, 44.91, 45.02, 42.81, 48.5 , 44.05, 45.11, 42.45,
# ...

# %%
df[' Estimated Unemployment Rate (%)']
# Out:
# 0       3.65
# 1       3.05
# 2       3.75
# 3       3.32
# 4       5.17
#        ...
# 749     7.55
# 750     6.67
# 751    15.63
# 752    15.22
# 753     9.86
# Name:  Estimated Unemployment Rate (%), Length: 741, dtype: float64

# %%
df[' Estimated Unemployment Rate (%)'].unique()
# Out:
# array([ 3.65,  3.05,  3.75,  3.32,  5.17,  3.52,  4.12,  4.38,  4.84,
#         5.91,  4.06, 16.29, 14.46,  0.85,  4.29,  5.08,  4.26,  5.79,
#         4.46,  4.65,  4.66,  3.26,  3.77,  9.38,  0.  ,  9.27, 10.2 ,
#        13.44, 11.  ,  8.87, 12.47, 12.4 , 10.16,  9.13,  9.61, 15.39,
#        45.09, 47.26, 20.49,  9.82,  6.76,  4.54,  4.64,  8.33,  6.96,
#         2.77,  6.11,  9.89,  7.89,  7.31,  7.64, 10.14, 12.56,  9.33,
#        11.07, 17.18, 12.5 , 15.84, 11.11, 16.97, 13.48, 13.81, 15.18,
#        20.69, 22.76, 21.14,  2.91,  5.45, 10.98,  1.98,  3.61,  7.21,
#        23.71,  3.54,  5.38, 15.91, 20.  ,  2.88,  4.77,  4.58,  3.7 ,
#         6.29,  4.91,  4.68,  3.46,  5.35,  6.64,  7.59, 12.  , 14.58,
#         1.41, 14.54, 23.08, 16.22, 30.94, 16.36, 24.17, 16.59, 29.56,
#        16.21, 27.19, 23.92, 41.61, 34.22, 35.57, 13.68, 11.43, 20.59,
#        18.56, 15.98, 15.81, 22.86, 19.46, 16.67, 15.42, 17.71,  2.13,
# ...

# %%
df['Area']
# Out:
# 0      Rural
# 1      Rural
# 2      Rural
# 3      Rural
# 4      Rural
#        ...
# 749    Urban
# 750    Urban
# 751    Urban
# 752    Urban
# 753    Urban
# Name: Area, Length: 741, dtype: object

# %%
df['Area'].unique()
# Out:
# array(['Rural', nan, 'Urban'], dtype=object)

# %%
## there are 3 categories

# %%
df[' Frequency'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel=' Frequency'>

# %%
df['Area'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Area'>

# %%
df[' Estimated Unemployment Rate (%)'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel=' Estimated Unemployment Rate (%)'>

# %%
# check the outlier
plt.figure(figsize=(20,10))
sns.boxplot(df)
# Out:
# <Axes: >

# %%
sns.displot(df[' Frequency'])

# %%
sns.displot(df['Area'])

# %%
sns.distplot(df[' Estimated Employed'])
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_17980\1333802338.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[' Estimated Employed'])
# <Axes: xlabel=' Estimated Employed', ylabel='Density'>

# %%
sns.distplot(df[' Estimated Labour Participation Rate (%)'])
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_17980\348499704.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[' Estimated Labour Participation Rate (%)'])
# <Axes: xlabel=' Estimated Labour Participation Rate (%)', ylabel='Density'>

# %%
sns.distplot(df[' Estimated Unemployment Rate (%)'])
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_17980\243454349.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[' Estimated Unemployment Rate (%)'])
# <Axes: xlabel=' Estimated Unemployment Rate (%)', ylabel='Density'>

# %%
df.head()
# Out:
#            Region         Date  Frequency   Estimated Unemployment Rate (%)  \
# 0  Andhra Pradesh   31-05-2019    Monthly                              3.65
# 1  Andhra Pradesh   30-06-2019    Monthly                              3.05
# 2  Andhra Pradesh   31-07-2019    Monthly                              3.75
# 3  Andhra Pradesh   31-08-2019    Monthly                              3.32
# 4  Andhra Pradesh   30-09-2019    Monthly                              5.17
#
#     Estimated Employed   Estimated Labour Participation Rate (%)   Area
# 0           11999139.0                                     43.24  Rural
# 1           11755881.0                                     42.05  Rural
# 2           12086707.0                                     43.50  Rural
# 3           12285693.0                                     43.97  Rural
# 4           12256762.0                                     44.68  Rural

# %%
## anouther dataset analysis
## load the dataset
df1=pd.read_csv('Unemployment_Rate_upto_11_2020.csv')

# %%
df1.head()
# Out:
#            Region         Date  Frequency   Estimated Unemployment Rate (%)  \
# 0  Andhra Pradesh   31-01-2020          M                              5.48
# 1  Andhra Pradesh   29-02-2020          M                              5.83
# 2  Andhra Pradesh   31-03-2020          M                              5.79
# 3  Andhra Pradesh   30-04-2020          M                             20.51
# 4  Andhra Pradesh   31-05-2020          M                             17.43
#
#     Estimated Employed   Estimated Labour Participation Rate (%) Region.1  \
# 0             16635535                                     41.02    South
# 1             16545652                                     40.90    South
# 2             15881197                                     39.18    South
# 3             11336911                                     33.10    South
# 4             12988845                                     36.46    South
#
#    longitude  latitude
# 0    15.9129     79.74
# ...

# %%
df1.shape
# Out:
# (267, 9)

# %%
## this datset is 267 rows and 9 columns

# %%
## check the columns
df1.columns
# Out:
# Index(['Region', ' Date', ' Frequency', ' Estimated Unemployment Rate (%)',
#        ' Estimated Employed', ' Estimated Labour Participation Rate (%)',
#        'Region.1', 'longitude', 'latitude'],
#       dtype='object')

# %%
## check the datatypes
df1.dtypes
# Out:
# Region                                       object
#  Date                                        object
#  Frequency                                   object
#  Estimated Unemployment Rate (%)            float64
#  Estimated Employed                           int64
#  Estimated Labour Participation Rate (%)    float64
# Region.1                                     object
# longitude                                   float64
# latitude                                    float64
# dtype: object

# %%
## summary odf the dataset
df1.describe()
# Out:
#         Estimated Unemployment Rate (%)   Estimated Employed  \
# count                        267.000000         2.670000e+02
# mean                          12.236929         1.396211e+07
# std                           10.803283         1.336632e+07
# min                            0.500000         1.175420e+05
# 25%                            4.845000         2.838930e+06
# 50%                            9.650000         9.732417e+06
# 75%                           16.755000         2.187869e+07
# max                           75.850000         5.943376e+07
#
#         Estimated Labour Participation Rate (%)   longitude    latitude
# count                                267.000000  267.000000  267.000000
# mean                                  41.681573   22.826048   80.532425
# std                                    7.845419    6.270731    5.831738
# min                                   16.770000   10.850500   71.192400
# ...

# %%
## all information about the datastet
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 267 entries, 0 to 266
# Data columns (total 9 columns):
#  #   Column                                    Non-Null Count  Dtype
# ---  ------                                    --------------  -----
#  0   Region                                    267 non-null    object
#  1    Date                                     267 non-null    object
#  2    Frequency                                267 non-null    object
#  3    Estimated Unemployment Rate (%)          267 non-null    float64
#  4    Estimated Employed                       267 non-null    int64
#  5    Estimated Labour Participation Rate (%)  267 non-null    float64
#  6   Region.1                                  267 non-null    object
#  7   longitude                                 267 non-null    float64
#  8   latitude                                  267 non-null    float64
# dtypes: float64(4), int64(1), object(4)
# memory usage: 18.9+ KB

# %%
## check the missing values
df1.isnull().sum()
# Out:
# Region                                      0
#  Date                                       0
#  Frequency                                  0
#  Estimated Unemployment Rate (%)            0
#  Estimated Employed                         0
#  Estimated Labour Participation Rate (%)    0
# Region.1                                    0
# longitude                                   0
# latitude                                    0
# dtype: int64

# %%
## chech the duplicated rows
df1.duplicated().sum()
# Out:
# 0

# %%
df1[' Date'].unique()
# Out:
# array([' 31-01-2020', ' 29-02-2020', ' 31-03-2020', ' 30-04-2020',
#        ' 31-05-2020', ' 30-06-2020', ' 31-07-2020', ' 31-08-2020',
#        ' 30-09-2020', ' 31-10-2020'], dtype=object)

# %%
df1[' Estimated Employed'].unique()
# Out:
# array([16635535, 16545652, 15881197, 11336911, 12988845, 19805400,
#        15431615, 15251776, 15220312, 15157557, 13051904, 10088268,
#        11542888,  6830817, 11367897,  9095944, 10286757,  9781310,
#        14107641, 11949329, 26397671, 26281655, 25717519, 16046236,
#        16280203, 23963933, 24989370, 23795534, 26902907, 25693252,
#         8552172,  9195114,  9302317,  7600448,  6991217,  7332807,
#         8620294,  9050422,  9021854,  8546847,  5805284,  5856307,
#         5553805,  3119274,  2632404,  4418914,  4291053,  4850107,
#         4958373,  4842698,   416750,   478068,   411761,   500614,
#          378244,   489111,   458876,   473016,   425004,   392304,
#        24126346, 24757795, 23566641, 15288878, 17836936, 23657055,
#        24276120, 22817232, 25010199, 25970259,  7693231,  7322942,
#         6641555,  5647630,  6437868,  6951934,  6800652,  7113788,
#         7132439,  6698551,  2287632,  2180268,  2021858,  1131128,
# ...

# %%
df1[' Estimated Labour Participation Rate (%)'].unique()
# Out:
# array([41.02, 40.9 , 39.18, 33.1 , 36.46, 47.41, 38.91, 37.83, 37.47,
#        37.34, 52.98, 40.77, 46.73, 29.55, 48.26, 35.07, 40.88, 39.52,
#        54.38, 46.84, 37.72, 37.35, 38.69, 38.17, 38.16, 36.86, 36.14,
#        34.59, 38.35, 35.7 , 43.08, 45.58, 45.59, 35.58, 35.23, 38.48,
#        43.14, 42.97, 41.14, 40.82, 47.79, 43.92, 42.65, 23.8 , 28.91,
#        34.17, 33.97, 35.41, 35.59, 32.36, 35.73, 38.38, 33.88, 44.97,
#        37.36, 42.21, 42.94, 43.76, 38.89, 34.3 , 48.49, 50.11, 47.75,
#        35.5 , 38.23, 45.96, 46.41, 43.55, 48.41, 50.49, 43.36, 44.21,
#        39.63, 44.38, 40.39, 42.14, 39.77, 47.32, 39.2 , 40.6 , 45.5 ,
#        43.3 , 41.04, 19.04, 42.7 , 41.72, 48.25, 39.42, 41.54, 40.01,
#        42.2 , 39.17, 38.18, 38.21, 37.24, 38.03, 36.66, 36.31, 35.05,
#        42.92, 44.4 , 39.34, 37.69, 37.92, 40.59, 38.27, 38.31, 42.18,
#        40.54, 42.78, 43.43, 47.29, 42.55, 43.13, 40.3 , 37.12, 37.71,
# ...

# %%
df1[' Estimated Unemployment Rate (%)'].unique()
# Out:
# array([ 5.48,  5.83,  5.79, 20.51, 17.43,  3.31,  8.34,  6.96,  6.4 ,
#         6.59,  4.66,  4.41,  4.77, 11.06,  9.55,  0.6 ,  3.77,  5.53,
#         1.19,  3.02, 10.61, 10.29, 15.43, 46.64, 45.96, 17.82, 12.79,
#        13.44, 11.91,  9.82,  9.65,  8.38,  7.54,  3.41, 10.5 , 14.23,
#        10.27,  5.63,  1.96,  6.62, 22.23, 14.84, 17.04, 16.68, 42.27,
#        18.19, 20.3 , 13.79, 12.53,  6.27,  8.89,  2.81,  5.25, 13.31,
#        21.25,  9.96, 17.07, 16.21, 15.38, 11.54,  5.54,  6.38,  6.66,
#        18.71, 12.11,  3.2 ,  1.84,  1.87,  3.42,  4.03, 20.34, 25.77,
#        25.05, 43.22, 29.02, 26.7 , 24.18, 33.5 , 19.68, 27.31, 16.83,
#        16.84, 18.76,  2.2 , 26.95, 13.47, 24.31, 15.79, 12.04, 13.46,
#        21.08, 20.78, 15.5 , 18.74, 17.92, 10.88, 11.09, 16.17, 16.14,
#        11.85,  8.23, 47.09, 59.23, 20.95,  7.63,  9.76,  8.24, 11.8 ,
#         2.86,  3.61,  3.46, 29.84, 19.97,  8.44,  4.01,  0.5 ,  2.41,
# ...

# %%
df1[' Frequency'].unique()
# Out:
# array([' M'], dtype=object)

# %%
df1['Region'].unique()
# Out:
# array(['Andhra Pradesh', 'Assam', 'Bihar', 'Chhattisgarh', 'Delhi', 'Goa',
#        'Gujarat', 'Haryana', 'Himachal Pradesh', 'Jammu & Kashmir',
#        'Jharkhand', 'Karnataka', 'Kerala', 'Madhya Pradesh',
#        'Maharashtra', 'Meghalaya', 'Odisha', 'Puducherry', 'Punjab',
#        'Rajasthan', 'Sikkim', 'Tamil Nadu', 'Telangana', 'Tripura',
#        'Uttar Pradesh', 'Uttarakhand', 'West Bengal'], dtype=object)

# %%
df1['Region.1'].unique()
# Out:
# array(['South', 'Northeast', 'East', 'West', 'North'], dtype=object)

# %%
df1['latitude'].unique()
# Out:
# array([79.74  , 92.9376, 85.3131, 81.8661, 77.1025, 74.124 , 71.1924,
#        76.0856, 77.1734, 76.5762, 85.2799, 75.7139, 76.2711, 78.6569,
#        91.3662, 85.0985, 79.8083, 75.3412, 74.2179, 88.5122, 79.0193,
#        91.9882, 80.9462, 87.855 ])

# %%
df1['longitude'].unique()
# Out:
# array([15.9129, 26.2006, 25.0961, 21.2787, 28.7041, 15.2993, 22.2587,
#        29.0588, 31.1048, 33.7782, 23.6102, 15.3173, 10.8505, 22.9734,
#        19.7515, 25.467 , 20.9517, 11.9416, 31.1471, 27.0238, 27.533 ,
#        11.1271, 18.1124, 23.9408, 26.8467, 30.0668, 22.9868])

# %%
df1[' Frequency'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel=' Frequency'>

# %%
df1['Region'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Region'>

# %%
df1['Region.1'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Region.1'>

# %%
df1['latitude'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='latitude'>

# %%
df1['longitude'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='longitude'>

# %%
df1[' Estimated Employed'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel=' Estimated Employed'>

# %%
# check the outlier
plt.figure(figsize=(20,10))
sns.boxplot(df1)
# Out:
# <Axes: >

# %%
sns.distplot(df1[' Estimated Labour Participation Rate (%)'])
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_17980\3396993294.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df1[' Estimated Labour Participation Rate (%)'])
# <Axes: xlabel=' Estimated Labour Participation Rate (%)', ylabel='Density'>

# %%
sns.distplot(df1['latitude'])
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_17980\4291396568.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df1['latitude'])
# <Axes: xlabel='latitude', ylabel='Density'>

# %%
sns.distplot(df1['longitude'])
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_17980\764742224.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df1['longitude'])
# <Axes: xlabel='longitude', ylabel='Density'>

# %%
sns.distplot(df1[' Estimated Employed'])
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_17980\2481424733.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df1[' Estimated Employed'])
# <Axes: xlabel=' Estimated Employed', ylabel='Density'>

# %%
sns.distplot(df1[' Estimated Unemployment Rate (%)'])
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_17980\983241681.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df1[' Estimated Unemployment Rate (%)'])
# <Axes: xlabel=' Estimated Unemployment Rate (%)', ylabel='Density'>
